# %%
import pandas as pd
import numpy as np

# %%
from pydataset import data

# %%
mpg = data('mpg')

# %%
Mammals = data('Mammals')

# %%
np.random.seed(123)

# %%
students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# %%
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

# %%
df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

# %% [markdown]
# - Create a column named passing_english that indicates whether each student has a passing grade in english.
# - Sort the english grades by the passing_english column. How are duplicates handled?
# -  Sort the english grades first by passing_english and then by student name. All the students that are failing english should be first, and within the students that are failing english they should be ordered alphabetically. The same should be true for the students passing english. (Hint: you can pass a list to the .sort_values method)
# - Sort the english grades first by passing_english, and then by the actual english grade, similar to how we did in the last step.
# - Calculate each students overall grade and add it as a column on the dataframe. The overall grade is the average of the math, english, and reading grades.

# %%
df['passing_english'] = df.english > 70

# %%
df
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True
# 11     Alan    92       62       72            False

# %%
df.sort_values(by = ['passing_english', 'name'], ascending = True)
# Out:
#        name  math  english  reading  passing_english
# 11     Alan    92       62       72            False
# 8    Albert    92       62       87            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True
# 1      Jane    88       79       67             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 2     Suzie    94       74       95             True

# %%
df.sort_values(by = ['passing_english', 'english'], ascending = True)
# Out:
#        name  math  english  reading  passing_english
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 2     Suzie    94       74       95             True
# 5      John    79       76       93             True
# 1      Jane    88       79       67             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True

# %%
df.drop(columns=['passing_english'])
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
df['overall_grade'] = (df.math + df.english + df.reading) / 3

# %%
df.drop(columns=['passing_english'])
# Out:
#        name  math  english  reading  overall_grade
# 0     Sally    62       85       80      75.666667
# 1      Jane    88       79       67      78.000000
# 2     Suzie    94       74       95      87.666667
# 3     Billy    98       96       88      94.000000
# 4       Ada    77       92       98      89.000000
# 5      John    79       76       93      82.666667
# 6    Thomas    82       64       81      75.666667
# 7     Marie    93       63       90      82.000000
# 8    Albert    92       62       87      80.333333
# 9   Richard    69       80       94      81.000000
# 10    Isaac    92       99       93      94.666667
# 11     Alan    92       62       72      75.333333

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %% [markdown]
# # EXERCISE part II  a-e
#
# - How many rows and columns are there?
# - What are the data types of each column?
# - Summarize the dataframe with .info and .describe
# - Rename the cty column to city.
# - Rename the hwy column to highway.

# %%
mpg.describe
# Out:
# <bound method NDFrame.describe of     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# ...

# %%
mpg.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class'],
#       dtype='object')

# %%
mpg.info
# Out:
# <bound method DataFrame.info of     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ...

# %%
mpg = mpg.rename(columns={'cty': 'city'})

# %%
mpg = mpg.rename(columns={'hwy': 'highway'})

# %% [markdown]
# # Exercises part II f-k
# - Do any cars have better city mileage than highway mileage?
# - Create a column named mileage_difference this column should contain the difference between highway and city mileage for each car.
# - Which car (or cars) has the highest mileage difference?
# - Which compact class car has the lowest highway mileage? The best?
# - Create a column named average_mileage that is the mean of the city and highway mileage.
# - Which dodge car has the best average mileage? The worst?

# %%
mpg['city'] = mpg['city'].astype(int)
mpg['highway'] = mpg['highway'].astype(int)

# %%
mpg[mpg.city > mpg.highway]
# Out:
# Empty DataFrame
# Columns: [manufacturer, model, displ, year, cyl, trans, drv, city, highway, fl, class]
# Index: []

# %%
mpg['fuel_eff_diff'] = mpg.highway - mpg.city
mpg.sort_values(by = 'fuel_eff_diff', ascending = False).head()
# Out:
#     manufacturer       model  displ  year  cyl     trans drv  city  highway  \
# 107        honda       civic    1.8  2008    4  auto(l5)   f    24       36
# 223   volkswagen  new beetle    1.9  1999    4  auto(l4)   f    29       41
# 1           audi          a4    1.8  1999    4  auto(l5)   f    18       29
# 229   volkswagen      passat    1.8  1999    4  auto(l5)   f    18       29
# 36     chevrolet      malibu    3.5  2008    6  auto(l4)   f    18       29
#
#     fl       class  fuel_eff_diff
# 107  c  subcompact             12
# 223  d  subcompact             12
# 1    p     compact             11
# 229  p     midsize             11
# 36   r     midsize             11

# %%
mpg[mpg.variety == 'compact'].sort_values(by = 'highway', ascending = True).tail(1)
#mpg = mpg.rename(columns={'class': 'variety'})
# Out:
#     manufacturer  model  displ  year  cyl       trans drv  city  highway fl  \
# 213   volkswagen  jetta    1.9  1999    4  manual(m5)   f    33       44  d
#
#      variety  mileage_difference  average_mileage
# 213  compact                  11             38.5

# %%
mpg[mpg.variety == 'compact'].sort_values(by = 'highway', ascending = True).head(1)
# Out:
#     manufacturer  model  displ  year  cyl     trans drv  city  highway fl  \
# 220   volkswagen  jetta    2.8  1999    6  auto(l4)   f    16       23  r
#
#      variety  mileage_difference  average_mileage
# 220  compact                   7             19.5

# %%
mpg['average_mileage'] = (mpg.highway + mpg.city) / 2
mpg = mpg.rename(columns={'fuel_eff_diff': 'mileage_difference'})
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %%
mpg[mpg.manufacturer == 'dodge'].sort_values(by = 'average_mileage', ascending = True).tail(1)
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  city  highway  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f    18       24
#
#    fl  variety  mileage_difference  average_mileage
# 38  r  minivan                   6             21.0

# %%
mpg[mpg.manufacturer == 'dodge'].sort_values(by = 'average_mileage', ascending = True).head(1)
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  city  \
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
#
#     highway fl variety  mileage_difference  average_mileage
# 70       12  e  pickup                   3             10.5

# %%
mpg.dtypes
# Out:
# manufacturer           object
# model                  object
# displ                 float64
# year                    int64
# cyl                     int64
# trans                  object
# drv                    object
# city                    int64
# highway                 int64
# fl                     object
# variety                object
# mileage_difference      int64
# average_mileage       float64
# dtype: object

# %% [markdown]
# - How many rows and columns are there?
# - What are the data types?
# - Summarize the dataframe with .info and .describe
# - What is the the weight of the fastest animal?
# - What is the overal percentage of specials?
# - How many animals are hoppers that are above the median speed? What percentage is this?

# %%
Mammals.shape
# Out:
# (107, 4)

# %%
Mammals.dtypes
# Out:
# weight      float64
# speed       float64
# hoppers        bool
# specials       bool
# dtype: object

# %%
Mammals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB

# %%
Mammals.describe()
# Out:
#             weight       speed
# count   107.000000  107.000000
# mean    278.688178   46.208411
# std     839.608269   26.716778
# min       0.016000    1.600000
# 25%       1.700000   22.500000
# 50%      34.000000   48.000000
# 75%     142.500000   65.000000
# max    6000.000000  110.000000

# %%
Mammals.sort_values(by = 'speed', ascending = False).head(1)
# Out:
#     weight  speed  hoppers  specials
# 53    55.0  110.0    False     False

# %%
num_spec = Mammals[Mammals.specials == True].count()
num_spec
total_mam = Mammals.count()
total_mam
perc_of_spec = num_spec / total_mam * 100
perc_of_spec['specials']
# Out:
# 9.345794392523365

# %%
med_speed = Mammals.speed.median()

# %%
hopper_mammals = Mammals[Mammals.hoppers == True]
hopper_mammals
# Out:
# weight      11
# speed       11
# hoppers     11
# specials    11
# dtype: int64

# %%
fast_hoppers = hopper_mammals.speed > med_speed
fast_hoppers
# Out:
# 82     False
# 85     False
# 86     False
# 96      True
# 97      True
# 98      True
# 99      True
# 100     True
# 101     True
# 102     True
# 103    False
# Name: speed, dtype: bool
